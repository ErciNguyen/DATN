# %%
import requests as rq
import pandas as pd
import config
import client
from ssi_fc_data import fc_md_client , model  
import ssi_fc_data
import test_Req_Res
import json

# %%
import test_Req_Res

# %%
daily= test_Req_Res.md_get_stock_price()
daily
# Out:
# {'data': [{'TradingDate': '31/05/2024',
#    'PriceChange': '-150',
#    'PerPriceChange': '-0.40',
#    'CeilingPrice': '37250',
#    'FloorPrice': '32450',
#    'RefPrice': '34850',
#    'OpenPrice': '34850',
#    'HighestPrice': '35000',
#    'LowestPrice': '34600',
#    'ClosePrice': '34700',
#    'AveragePrice': '34816',
#    'ClosePriceAdjusted': '34700',
#    'TotalMatchVol': '8441300',
#    'TotalMatchVal': '293895860000',
#    'TotalDealVal': '6013200',
#    'TotalDealVol': '172',
#    'ForeignBuyVolTotal': '646200',
#    'ForeignCurrentRoom': '854865298',
#    'ForeignSellVolTotal': '1535614',
#    'ForeignBuyValTotal': '22423140000',
#    'ForeignSellValTotal': '53285805800',
#    'TotalBuyTrade': '0',
#    'TotalBuyTradeVol': '0',
#    'TotalSellTrade': '0',
#    'TotalSellTradeVol': '0',
#    'NetBuySellVol': '-889414',
#    'NetBuySellVal': '-30862665800',
#    'TotalTradedVol': '8441472',
#    'TotalTradedValue': '293901873200',
#    'Symbol': 'SSI',
# ...

# %%
daily
# Out:
# {'data': [{'TradingDate': '31/05/2024',
#    'PriceChange': '-150',
#    'PerPriceChange': '-0.40',
#    'CeilingPrice': '37250',
#    'FloorPrice': '32450',
#    'RefPrice': '34850',
#    'OpenPrice': '34850',
#    'HighestPrice': '35000',
#    'LowestPrice': '34600',
#    'ClosePrice': '34700',
#    'AveragePrice': '34816',
#    'ClosePriceAdjusted': '34700',
#    'TotalMatchVol': '8441300',
#    'TotalMatchVal': '293895860000',
#    'TotalDealVal': '6013200',
#    'TotalDealVol': '172',
#    'ForeignBuyVolTotal': '646200',
#    'ForeignCurrentRoom': '854865298',
#    'ForeignSellVolTotal': '1535614',
#    'ForeignBuyValTotal': '22423140000',
#    'ForeignSellValTotal': '53285805800',
#    'TotalBuyTrade': '0',
#    'TotalBuyTradeVol': '0',
#    'TotalSellTrade': '0',
#    'TotalSellTradeVol': '0',
#    'NetBuySellVol': '-889414',
#    'NetBuySellVal': '-30862665800',
#    'TotalTradedVol': '8441472',
#    'TotalTradedValue': '293901873200',
#    'Symbol': 'SSI',
# ...

# %%
a= test_Req_Res.md_get_securities_list()
# Out:
# Total records: 539
#     Market Symbol                  StockName  \
# 0     HOSE    AAA     Ctcp Nhua An Phat Xanh
# 1     HOSE    AAM       Ctcp Thuy San Mekong
# 2     HOSE    AAT        Ctcp Td Tien Son Th
# 3     HOSE    ABR     Ctcp Dt Nhan Hieu Viet
# 4     HOSE    ABS      Ctcp Dv Nn Binh Thuan
# ..     ...    ...                        ...
# 534   HOSE    VTB  Ctcp Viettronics Tan Binh
# 535   HOSE    VTO    Ctcp Vt Xang Dau Vitaco
# 536   HOSE    VTP    Tctcp Buu Chinh Viettel
# 537   HOSE    YBM  Ctcp Khoangsan Cn Yen Bai
# 538   HOSE    YEG        Ctcp Tap Doan Yeah1
#
#                                            StockEnName
# 0              An Phat Bioplastics Joint Stock Company
# 1                 Mekong Fisheries Joint Stock Company
# 2         Tien Son Thanh Hoa Group Joint Stock Company
# 3                Viet Brand Invest Joint Stock Company
# 4    BinhThuan Agriculture Services Joint Stock Com...
# ..                                                 ...
# ...

# %%
a=test_Req_Res.md_get_securities_details_OHLC()
# Out:
# Total records: 28
# Isin                                            None
# Symbol                                           ACB
# SymbolName                     NGAN HANG TMCP A CHAU
# SymbolEngName       Asia Commercial Joint Stock Bank
# SecType                                            S
# MarketId                                        HOSE
# Exchange                                        HOSE
# Issuer                                          None
# LotSize                                          100
# IssueDate
# MaturityDate
# FirstTradingDate
# LastTradingDate
# ContractMultiplier                                 0
# SettlMethod                                        C
# Underlying                                      None
# PutOrCall                                       None
# ExercisePrice                                      0
# ExerciseStyle
# ExcerciseRatio                                     0
# ListedShare                               4466657912
# ...

# %%
a= test_Req_Res.md_get_index_components()

print(a)
# Out:
# {'data': [{'IndexCode': 'VN100', 'IndexName': 'VN100', 'Exchange': 'HOSE', 'TotalSymbolNo': '100', 'IndexComponent': [{'Isin': 'AAA', 'StockSymbol': 'AAA'}, {'Isin': 'ACB', 'StockSymbol': 'ACB'}, {'Isin': 'AGG', 'StockSymbol': 'AGG'}, {'Isin': 'ANV', 'StockSymbol': 'ANV'}, {'Isin': 'ASM', 'StockSymbol': 'ASM'}, {'Isin': 'BCG', 'StockSymbol': 'BCG'}, {'Isin': 'BCM', 'StockSymbol': 'BCM'}, {'Isin': 'BID', 'StockSymbol': 'BID'}, {'Isin': 'BMP', 'StockSymbol': 'BMP'}, {'Isin': 'BSI', 'StockSymbol': 'BSI'}, {'Isin': 'BVH', 'StockSymbol': 'BVH'}, {'Isin': 'BWE', 'StockSymbol': 'BWE'}, {'Isin': 'CII', 'StockSymbol': 'CII'}, {'Isin': 'CMG', 'StockSymbol': 'CMG'}, {'Isin': 'CRE', 'StockSymbol': 'CRE'}, {'Isin': 'CTD', 'StockSymbol': 'CTD'}, {'Isin': 'CTG', 'StockSymbol': 'CTG'}, {'Isin': 'CTR', 'StockSymbol': 'CTR'}, {'Isin': 'DBC', 'StockSymbol': 'DBC'}, {'Isin': 'DCM', 'StockSymbol': 'DCM'}, {'Isin': 'DGC', 'StockSymbol': 'DGC'}, {'Isin': 'DGW', 'StockSymbol': 'DGW'}, {'Isin': 'DHC', 'Stock
# ...

# %%
a= test_Req_Res.md_get_daily_index()
data = pd.DataFrame(a)
# Out:
# {'data': [{'IndexId': 'VN100', 'IndexValue': '1298.75', 'TradingDate': '29/05/2024', 'Time': None, 'Change': '-10.52', 'RatioChange': '-0.8035', 'TotalTrade': '0', 'TotalMatchVol': '670112500', 'TotalMatchVal': '18714037000000', 'TypeIndex': None, 'IndexName': 'VN100', 'Advances': '27', 'NoChanges': '4', 'Declines': '69', 'Ceilings': '1', 'Floors': '0', 'TotalDealVol': '86370278', 'TotalDealVal': '2086549000000', 'TotalVol': '756482778', 'TotalVal': '20800586000000', 'TradingSession': 'C'}], 'message': 'Success', 'status': 'Success', 'totalRecord': 1}

# %%
a= test_Req_Res.md_get_intraday_OHLC1()
print(a)
# Out:
#                                                   data  message   status  \
# 0    {'Symbol': 'VND', 'Value': '18000', 'TradingDa...  Success  Success
# 1    {'Symbol': 'VND', 'Value': '18000', 'TradingDa...  Success  Success
# 2    {'Symbol': 'VND', 'Value': '17950', 'TradingDa...  Success  Success
# 3    {'Symbol': 'VND', 'Value': '17950', 'TradingDa...  Success  Success
# 4    {'Symbol': 'VND', 'Value': '17950', 'TradingDa...  Success  Success
# ..                                                 ...      ...      ...
# 221  {'Symbol': 'VND', 'Value': '17750', 'TradingDa...  Success  Success
# 222  {'Symbol': 'VND', 'Value': '17750', 'TradingDa...  Success  Success
# 223  {'Symbol': 'VND', 'Value': '17850', 'TradingDa...  Success  Success
# 224  {'Symbol': 'VND', 'Value': '17850', 'TradingDa...  Success  Success
# 225  {'Symbol': 'VND', 'Value': '17750', 'TradingDa...  Success  Success
#
#      totalRecord
# 0            226
# 1            226
# 2            226
# 3            226
# ...

# %%
a= test_Req_Res.md_get_intraday_OHLC1()
data = pd.DataFrame(a)

print(a)
# Out:
#                                                   data  message   status  \
# 0    {'Symbol': 'VND', 'Value': '18000', 'TradingDa...  Success  Success
# 1    {'Symbol': 'VND', 'Value': '18000', 'TradingDa...  Success  Success
# 2    {'Symbol': 'VND', 'Value': '17950', 'TradingDa...  Success  Success
# 3    {'Symbol': 'VND', 'Value': '17950', 'TradingDa...  Success  Success
# 4    {'Symbol': 'VND', 'Value': '17950', 'TradingDa...  Success  Success
# ..                                                 ...      ...      ...
# 221  {'Symbol': 'VND', 'Value': '17750', 'TradingDa...  Success  Success
# 222  {'Symbol': 'VND', 'Value': '17750', 'TradingDa...  Success  Success
# 223  {'Symbol': 'VND', 'Value': '17850', 'TradingDa...  Success  Success
# 224  {'Symbol': 'VND', 'Value': '17850', 'TradingDa...  Success  Success
# 225  {'Symbol': 'VND', 'Value': '17750', 'TradingDa...  Success  Success
#
#      totalRecord
# 0            226
# 1            226
# 2            226
# 3            226
# ...

# %%
a= test_Req_Res.md_get_daily_OHLC()
print (a)
# Out:
#    Symbol Market TradingDate   Open   High    Low  Close    Volume  \
# 0     SSI   HOSE  2024-05-02  35200  35300  34300  34700  12220400
# 1     SSI   HOSE  2024-05-03  35100  35300  34600  34650   9163900
# 2     SSI   HOSE  2024-05-06  35000  36050  34950  35650  16789600
# 3     SSI   HOSE  2024-05-07  35800  36000  35400  35550   8273300
# 4     SSI   HOSE  2024-05-08  35200  35900  35100  35650  13710900
# 5     SSI   HOSE  2024-05-09  35850  35900  35050  35200  15342900
# 6     SSI   HOSE  2024-05-10  35300  35500  35000  35450  12118500
# 7     SSI   HOSE  2024-05-13  35650  35900  35250  35600  10272700
# 8     SSI   HOSE  2024-05-14  35650  35900  35350  35500   7029000
# 9     SSI   HOSE  2024-05-15  35700  36300  35500  35950  20293600
# 10    SSI   HOSE  2024-05-16  36350  36400  36050  36100  13615900
# 11    SSI   HOSE  2024-05-17  36100  36600  35950  36400  14815700
# 12    SSI   HOSE  2024-05-20  36600  37100  36500  36650  19945200
# ...

# %%
import yfinance as yf
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme()

# %%
a= test_Req_Res.md_get_daily_OHLC()
a.plot(figsize=(15,8), fontsize=12)
plt.legend(fontsize=12)
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Dữ liệu mẫu
data = {
    'Symbol': ['SSI', 'SSI', 'SSI', 'SSI', 'SSI', 'SSI', 'SSI', 'SSI'],
    'Market': ['HOSE']*8,
    'TradingDate': ['2024-05-02', '2024-05-03', '2024-05-06', '2024-05-07', '2024-05-08', '2024-05-09', '2024-05-10', '2024-05-13'],
    'Open': [35200, 35100, 35000, 35800, 35200, 35850, 35300, 35650],
    'High': [35300, 35300, 36050, 36000, 35900, 35900, 35500, 35900],
    'Low': [34300, 34600, 34950, 35400, 35100, 35050, 35000, 35250],
    'Close': [34700, 34650, 35650, 35550, 35650, 35200, 35450, 35600],
    'Volume': [12220400, 9163900, 16789600, 8273300, 13710900, 15342900, 12118500, 10272700],
    'Value': [423229455000.008, 320563305000.0, 597307395000.002, 294423980000.0, 487382695000.0, 542720695000.011, 427444765000.002, 366203345000.0]
}

# Chuyển dữ liệu thành DataFrame
df = pd.DataFrame(data)
df['TradingDate'] = pd.to_datetime(df['TradingDate'])

# Đặt 'TradingDate' làm chỉ mục
df.set_index('TradingDate', inplace=True)

# Vẽ biểu đồ
plt.figure(figsize=(15, 8))
for column in ['Open', 'High', 'Low', 'Close', 'Volume', 'Value']:
    plt.plot(df.index, df[column], label=column, linewidth=2)

plt.title("Biểu Đồ Giá Trị của SSI", fontsize=16)
plt.xlabel("Ngày", fontsize=14)
plt.ylabel("Giá Trị", fontsize=14)
plt.xticks(fontsize=12, rotation=45)
plt.yticks(fontsize=12)
plt.grid(True, linestyle='--', alpha=0.7)
plt.legend(fontsize=12)
plt.tight_layout()
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# Dữ liệu mẫu
data = {
    'Symbol': ['SSI', 'SSI', 'SSI', 'SSI', 'SSI', 'SSI', 'SSI', 'SSI'],
    'Market': ['HOSE']*8,
    'TradingDate': ['2024-05-02', '2024-05-03', '2024-05-06', '2024-05-07', '2024-05-08', '2024-05-09', '2024-05-10', '2024-05-13'],
    'Open': [35200, 35100, 35000, 35800, 35200, 35850, 35300, 35650],
    'High': [35300, 35300, 36050, 36000, 35900, 35900, 35500, 35900],
    'Low': [34300, 34600, 34950, 35400, 35100, 35050, 35000, 35250],
    'Close': [34700, 34650, 35650, 35550, 35650, 35200, 35450, 35600],
    'Volume': [12220400, 9163900, 16789600, 8273300, 13710900, 15342900, 12118500, 10272700],
    'Value': [423229455000.008, 320563305000.0, 597307395000.002, 294423980000.0, 487382695000.0, 542720695000.011, 427444765000.002, 366203345000.0]
}

# Chuyển dữ liệu thành DataFrame
df = pd.DataFrame(data)
df['TradingDate'] = pd.to_datetime(df['TradingDate'])

# Chọn các cột cần thiết và đặt 'TradingDate' làm chỉ mục
df.set_index('TradingDate', inplace=True)
heatmap_data = df[['Open', 'High', 'Low', 'Close', 'Volume', 'Value']]

# Tạo biểu đồ
plt.figure(figsize=(12, 8))
sns.heatmap(heatmap_data, annot=True, fmt=".0f", cmap="YlGnBu", linewidths=.5, cbar_kws={'label': 'Value'})
plt.title("Biểu Đồ Nhiệt cho các giá trị của SSI", fontsize=16)
plt.xlabel("Các chỉ số", fontsize=14)
plt.ylabel("Ngày", fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.tight_layout()
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# Random state for reproducibility
rng = np.random.RandomState(0)

# Sample data
data = {
    'Symbol': ['SSI', 'SSI', 'SSI', 'SSI', 'SSI', 'SSI', 'SSI', 'SSI'],
    'Market': ['HOSE']*8,
    'TradingDate': ['2024-05-02', '2024-05-03', '2024-05-06', '2024-05-07', '2024-05-08', '2024-05-09', '2024-05-10', '2024-05-13'],
    'Open': [35200, 35100, 35000, 35800, 35200, 35850, 35300, 35650],
    'High': [35300, 35300, 36050, 36000, 35900, 35900, 35500, 35900],
    'Low': [34300, 34600, 34950, 35400, 35100, 35050, 35000, 35250],
    'Close': [34700, 34650, 35650, 35550, 35650, 35200, 35450, 35600],
    'Volume': [12220400, 9163900, 16789600, 8273300, 13710900, 15342900, 12118500, 10272700],
    'Value': [423229455000.008, 320563305000.0, 597307395000.002, 294423980000.0, 487382695000.0, 542720695000.011, 427444765000.002, 366203345000.0]
}

# Convert data to DataFrame
df = pd.DataFrame(data)
df['TradingDate'] = pd.to_datetime(df['TradingDate'])

# Select necessary columns and set 'TradingDate' as index
x = df['Close']
y = df['TradingDate']

# Generate appropriate colors and sizes arrays
colors = rng.randn(len(x))
sizes = 1000 * rng.rand(len(x))

# Create scatter plot
fig, ax = plt.subplots()
scatter = ax.scatter(x, y, c=colors, cmap='YlGnBu', alpha=0.3, s=sizes)

# Add color bar
plt.colorbar(scatter, ax=ax)

# Show plot
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# Dữ liệu mẫu
data = {
    'Symbol': ['SSI', 'SSI', 'SSI', 'SSI', 'SSI', 'SSI', 'SSI', 'SSI'],
    'Market': ['HOSE']*8,
    'TradingDate': ['2024-05-02', '2024-05-03', '2024-05-06', '2024-05-07', '2024-05-08', '2024-05-09', '2024-05-10', '2024-05-13'],
    'Open': [35200, 35100, 35000, 35800, 35200, 35850, 35300, 35650],
    'High': [35300, 35300, 36050, 36000, 35900, 35900, 35500, 35900],
    'Low': [34300, 34600, 34950, 35400, 35100, 35050, 35000, 35250],
    'Close': [34700, 34650, 35650, 35550, 35650, 35200, 35450, 35600],
    'Volume': [12220400, 9163900, 16789600, 8273300, 13710900, 15342900, 12118500, 10272700],
    'Value': [423229455000.008, 320563305000.0, 597307395000.002, 294423980000.0, 487382695000.0, 542720695000.011, 427444765000.002, 366203345000.0]
}

# Chuyển dữ liệu thành DataFrame
df = pd.DataFrame(data)
df['TradingDate'] = pd.to_datetime(df['TradingDate'])

# Tạo bảng xoay (pivot table) để có dữ liệu cho biểu đồ nhiệt
pivot_table = df.pivot("TradingDate", "Close", "Volume")

# Vẽ biểu đồ nhiệt
plt.figure(figsize=(10, 8))
sns.heatmap(pivot_table, cmap='viridis', annot=True, fmt='.0f')
plt.title('Biểu đồ nhiệt của Volume theo Close và TradingDate')
plt.xlabel('Giá đóng cửa (Close)')
plt.ylabel('Ngày giao dịch (TradingDate)')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 24
#      21 df['TradingDate'] = pd.to_datetime(df['TradingDate'])
#      23 # Tạo bảng xoay (pivot table) để có dữ liệu cho biểu đồ nhiệt
# ---> 24 pivot_table = df.pivot("TradingDate", "Close", "Volume")
#      26 # Vẽ biểu đồ nhiệt
#      27 plt.figure(figsize=(10, 8))
#
# TypeError: pivot() takes 1 positional argument but 4 were given

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# Dữ liệu mẫu
data = {
    'Symbol': ['SSI', 'SSI', 'SSI', 'SSI', 'SSI', 'SSI', 'SSI', 'SSI'],
    'Market': ['HOSE']*8,
    'TradingDate': ['2024-05-02', '2024-05-03', '2024-05-06', '2024-05-07', '2024-05-08', '2024-05-09', '2024-05-10', '2024-05-13'],
    'Open': [35200, 35100, 35000, 35800, 35200, 35850, 35300, 35650],
    'High': [35300, 35300, 36050, 36000, 35900, 35900, 35500, 35900],
    'Low': [34300, 34600, 34950, 35400, 35100, 35050, 35000, 35250],
    'Close': [34700, 34650, 35650, 35550, 35650, 35200, 35450, 35600],
    'Volume': [12220400, 9163900, 16789600, 8273300, 13710900, 15342900, 12118500, 10272700],
    'Value': [423229455000.008, 320563305000.0, 597307395000.002, 294423980000.0, 487382695000.0, 542720695000.011, 427444765000.002, 366203345000.0]
}

# Chuyển dữ liệu thành DataFrame
df = pd.DataFrame(data)
df['TradingDate'] = pd.to_datetime(df['TradingDate'])

# Tạo bảng xoay (pivot table) để có dữ liệu cho biểu đồ nhiệt
pivot_table = df.pivot_table(values='Volume', index='TradingDate', columns='Close', aggfunc='mean')

# Vẽ biểu đồ nhiệt
plt.figure(figsize=(10, 8))
sns.heatmap(pivot_table, cmap='viridis', annot=True, fmt='.0f')
plt.title('Biểu đồ nhiệt của Volume theo Close và TradingDate')
plt.xlabel('Giá đóng cửa (Close)')
plt.ylabel('Ngày giao dịch (TradingDate)')
plt.show()

# %%
import pandas as pd
import mplfinance as mpf
import plotly.graph_objects as go

# Sample data
data = {
    'Date': ['2024-05-02', '2024-05-03', '2024-05-06', '2024-05-07', '2024-05-08', '2024-05-09', '2024-05-10', '2024-05-13'],
    'Open': [35200, 35100, 35000, 35800, 35200, 35850, 35300, 35650],
    'High': [35300, 35300, 36050, 36000, 35900, 35900, 35500, 35900],
    'Low': [34300, 34600, 34950, 35400, 35100, 35050, 35000, 35250],
    'Close': [34700, 34650, 35650, 35550, 35650, 35200, 35450, 35600],
    'Volume': [12220400, 9163900, 16789600, 8273300, 13710900, 15342900, 12118500, 10272700]
}

# Convert data to DataFrame and set 'Date' as index
df = pd.DataFrame(data)
df['Date'] = pd.to_datetime(df['Date'])
df.set_index('Date', inplace=True)

# Plot candlestick chart with mplfinance
mpf.plot(df, type='candle', style='yahoo', volume=True, ylabel='Price', ylabel_lower='Volume', figsize=(12, 8), tight_layout=True)

# Create Candlestick chart with plotly
fig = go.Figure()
fig.add_trace(go.Candlestick(
    x=df.index, open=df['Open'], high=df['High'], low=df['Low'], close=df['Close'],
    line=dict(width=1), opacity=1,
    increasing_fillcolor='#24A06B',
    decreasing_fillcolor="#CC2E3C",
    increasing_line_color='#2EC886',
    decreasing_line_color='#FF3A4C'
))
fig.update_layout(
    width=1000, height=600,
    margin=dict(l=10, r=10, b=10, t=10),
    font=dict(size=10, color="#e1e1e1"),
    paper_bgcolor="#1e1e1e",
    plot_bgcolor="#1e1e1e"
)
fig.update_xaxes(
    gridcolor="#1f292f",
    showgrid=True, fixedrange=True, rangeslider=dict(visible=False)
)
fig.update_yaxes(
    gridcolor="#1f292f",
    showgrid=True
)
fig.show()

# %%
import pandas as pd
import mplfinance as mpf
import plotly.graph_objects as go

# Sample data
data = {
    'Date': ['2024-05-02', '2024-05-03', '2024-05-06', '2024-05-07', '2024-05-08', '2024-05-09', '2024-05-10', '2024-05-13'],
    'Open': [35200, 35100, 35000, 35800, 35200, 35850, 35300, 35650],
    'High': [35300, 35300, 36050, 36000, 35900, 35900, 35500, 35900],
    'Low': [34300, 34600, 34950, 35400, 35100, 35050, 35000, 35250],
    'Close': [34700, 34650, 35650, 35550, 35650, 35200, 35450, 35600],
    'Volume': [12220400, 9163900, 16789600, 8273300, 13710900, 15342900, 12118500, 10272700]
}

# Convert data to DataFrame and set 'Date' as index
df = pd.DataFrame(data)
df['Date'] = pd.to_datetime(df['Date'])
df.set_index('Date', inplace=True)

# Plot candlestick chart with mplfinance
mpf.plot(df, type='candle', style='yahoo', volume=True, ylabel='Price', ylabel_lower='Volume', figsize=(12, 8), tight_layout=True)

# Create Candlestick chart with plotly
fig = go.Figure()
fig.add_trace(go.Candlestick(
    x=df.index, open=df['Open'], high=df['High'], low=df['Low'], close=df['Close'],
    line=dict(width=1), opacity=1,
    increasing_fillcolor='#24A06B',
    decreasing_fillcolor="#CC2E3C",
    increasing_line_color='#2EC886',
    decreasing_line_color='#FF3A4C'
))
fig.update_layout(
    width=1000, height=600,
    margin=dict(l=10, r=10, b=10, t=10),
    font=dict(size=10, color="#e1e1e1"),
    paper_bgcolor="#1e1e1e",
    plot_bgcolor="#1e1e1e"
)
fig.update_xaxes(
    gridcolor="#1f292f",
    showgrid=True, fixedrange=True, rangeslider=dict(visible=False)
)
fig.update_yaxes(
    gridcolor="#1f292f",
    showgrid=True
)
fig.show()
